# %% [markdown]
# # Project NETLIST: CGHD Dataset Exploration Notebook
#
# Interactive exploration of the Common Graphical Hand-Drawn Circuit Diagram (CGHD) dataset.

# %%
from src.data.dataset_inspector import DatasetInspector
inspector = DatasetInspector(data_dir='data/raw/cghd', classes_file='classes.json')
stats = inspector.inspect()
inspector.print_summary(stats)
