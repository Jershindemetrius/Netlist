# %% [markdown]
# # Project NETLIST: Google Colab GPU Training Workflow
#
# This notebook provides a seamless execution pipeline for training the **Ultralytics YOLO11s** symbol detector on Google Colab GPU with persistent checkpoints saved to Google Drive.

# %%
# 1. Mount Google Drive for persistent checkpoint saving
from google.colab import drive
drive.mount('/content/drive')
import os
os.makedirs('/content/drive/MyDrive/netlist_checkpoints', exist_ok=True)
print('Google Drive mounted successfully!')

# %%
# 2. Install dependencies & PyTorch/CUDA verification
# !pip install -q ultralytics opencv-python scikit-image networkx pydantic PyYAML schemdraw lxml pytest
import torch
print(f'PyTorch Version: {torch.__version__}')
print(f'CUDA Available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'Device Name: {torch.cuda.get_device_name(0)}')

# %%
# 3. Run Dataset Preparation (Drafter Split & VOC -> YOLO conversion)
# !python scripts/prepare_dataset.py --seed 42

# %%
# 4. Launch YOLO11s Training
# !python scripts/train_detector.py --config configs/detection.yaml
